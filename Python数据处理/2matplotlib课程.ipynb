# %% [markdown]
# # 开始🎉

# %% [markdown]
# ## 简介

# %% [raw]
# 学习视频地址：
# https://www.bilibili.com/video/BV1Jx411L7LU?from=search&seid=3123883071080057053
# 通过 Matplotlib，开发者可以仅需要几行代码，便可以生成绘图，直方图，功率谱，条形图，错误图，散点图等。

# %% [markdown]
# # 基本用法

# %%
import pylab as plt
import numpy as np
import pandas as pd
# plt.rcParams['font.sans-serif']=['Arial Unicode MS']  #MacOS
plt.rcParams['font.sans-serif']=['SimHei'] #Windows
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
# %matplotlib inline

# %% [markdown]
# ## 基本显示

# %%
x=np.linspace(-1,1,50)
# y=2*x+1
y = x**2
plt.plot(x,y)

# %% [markdown]
# # 参数

# %% [markdown]
# ## 多figure显示

# %%
x=np.linspace(-3,3,50)
y1 = 2*x+1
y2 = x**2
plt.figure()
plt.plot(x,y1)

plt.figure(num=3,figsize=(8,5))#
plt.plot(x,y1,c='red',linewidth=2.0,linestyle='--')
#linestyle包括四种['--','-.','-'(default),':']
plt.plot(x,y2)

# %% [markdown]
# ## 修改坐标轴参数

# %%
# 限制坐标轴的取值范围
plt.xlim((-1,2)) 
plt.ylim((-2,3))
# 设置坐标轴的标签

plt.xlabel('这是x轴',fontsize=14)
plt.ylabel('这是y轴',color='red')
new_ticks=np.linspace(-1,2,5)
plt.xticks(new_ticks)
# 添加标记
plt.yticks([-2,-1.8,-1,1.22,3],
          ['really bad','bad','normal','good','very good'])


plt.title("大标题",fontsize=25)
plt.figure(num=3,figsize=(20,15))

# %%
# gca（get current axis）
ax=plt.gca()
# 使右边和上边的坐标轴不显示 spines,脊柱
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# ax.xaxis.set_ticks_position('top')# 将x轴显示的位置设置为底部，默认底部，也可以设置成其他位置
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
plt.plot(x,y1,c='red',linewidth=2.0,linestyle='--',label='down')
plt.plot(x,y2,c='blue',linewidth=2.0,linestyle=':',label='up')
ax.spines['bottom'].set_position(('data',1))
ax.spines['left'].set_position(('data',1))
plt.legend(loc='best') #给图加上图例  也可以使用这个方法 plt.legend(['1','2'])  loc可以有很多[lower upper center]+[ right left center]


plt
# Out:
# <module 'pylab' from '/Users/marc/miniforge3/envs/py39/lib/python3.9/site-packages/pylab.py'>

# %% [markdown]
# ## 添加注解 annotation

# %%
ax=plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
plt.plot(x,y1,c='blue',linewidth=2.0,linestyle='--',label='down')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))

# 添加一个点
x0=1
y0=2*x0+1
plt.scatter(x0,y0,c='red',s=50)

#添加一条线段
plt.plot([x0,x0],[0,y0],'k--',lw=2.5) # 'k--' 表示颜色为黑色，使用‘--’的linestyle ，lw=linewidth

#添加annotation的方式1:  坐标 coordinate
plt.annotate(r'$2x+1=%s$'%y0,xy=(x0,y0),xycoords='data',xytext=(+30,-30),textcoords='offset points',# xy=（坐标） 这个注解的位置 xytext设定偏移量
             arrowprops=dict(arrowstyle='->',connectionstyle='arc3,rad=.5')) #arrowprops是字典类型 可以设置弧度

#添加annotation的方式2:
textx,texty=(-3,4)
plt.text(textx,texty,r'$This\ is\ the\ some\ text.\ \mu\ \sigma_i\ \alpha_t$',fontdict={'size':10,'color':'red'})

plt
# Out:
# <module 'pylab' from 'c:\\users\\administrator\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\pylab.py'>

# %% [markdown]
# ## ticket能见度

# %%
x=np.linspace(-3,3,50)
y=0.1*x

plt.figure()
plt.plot(x,y,lw=8)
plt.ylim(-2,2)
ax =plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))

#获得标签
# ax.get_xticklabels()
# ax.get_yticklabels()
for label in ax.get_xticklabels()+ ax.get_yticklabels(): #所有的x轴和y轴标签
    label.set_fontsize(12)
    label.set_bbox(dict(facecolor='yellow',edgecolor='black',alpha=1))

plt
# Out:
# <module 'pylab' from 'c:\\users\\administrator\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\pylab.py'>

# %% [markdown]
# # 特殊图

# %% [markdown]
# ## Scatter散点图

# %%
# 建议重启内核
n=1024
X=np.random.normal(0,1,n)
Y=np.random.normal(0,1,n)
T=np.arctan2(Y,X) #用来对颜色进行赋值
plt.scatter(X,Y,s=35,c=T,alpha=.5)
plt.xlim((-1.5,1.5))
plt.ylim((-1.5,1.5))

#设置ticks为空
plt.xticks(())
plt.yticks(())
plt
# Out:
# <module 'pylab' from 'c:\\users\\administrator\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\pylab.py'>

# %% [markdown]
# ## Bar柱状图

# %%
n=12 #柱状图的数量
X=np.arange(n)
Y1=(1-X/float(n))*np.random.uniform(0.5,1.0,n) #均匀分布 0.5-1之间的12个均匀分布数 属于ndarray
Y2=(1-X/float(n))*np.random.uniform(0.5,1.0,n)

plt.bar(X,+Y1,facecolor='#9999ff',edgecolor='white')
plt.bar(X,-Y2,facecolor='#ff9999',edgecolor='white')
#添加文字
for x,y in zip(X,Y1):
    plt.text(x+0.2,y+0.05,'%.2f'%y,ha='center',va='bottom') # ha=horizontal alignment
for x,y in zip(X,-Y2):
    plt.text(x+0.2,y-0.1,'%.2f'%y,ha='center',va='top') # ha=horizontal alignment
plt.xlim(-.5,n)
plt.xticks(())
plt.ylim(-1.5,1.5)
plt.yticks(())
# Out:
# ([], [])

# %% [markdown]
# ## Contours等高线图

# %%
def f(x,y):
    # 计算高度的方法
    return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)

n = 256
x = np.linspace(-3,3,n)
y = np.linspace(-3,3,n)

X,Y=np.meshgrid(x,y) # 转为等高线的网格坐标

# 添加热成像'图'f=fill 
plt.contourf(X,Y,f(X,Y),4,alpha=.8,cmap=plt.cm.hot)# 1是高度规模,自动将高度分为9类

#添加等高'线'
C=plt.contour(X,Y,f(X,Y),4,colors='black',linewidths=.5)
#添加标签
plt.clabel(C,inline=True,fontsize=8)

plt.xticks(())
plt.yticks(())
plt
# Out:
# <module 'pylab' from 'c:\\users\\administrator\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\pylab.py'>

# %% [markdown]
# ## Image图像

# %%
# image数据
a = np.array([0.31,0.36,0.423,
             0.35,0.43,0.52,
             0.425,0.53,0.61]).reshape(3,3)

#显示图像
plt.imshow(a,interpolation='nearest',cmap='bone',origin='lower')
#添加colorbar
plt.colorbar(shrink=.9)#压缩高度

plt.xticks(())
plt.yticks(())
# Out:
# ([], [])

# %% [markdown]
# ## 3D图像

# %%
# 添加3D模块
from mpl_toolkits.mplot3d import Axes3D

fig=plt.figure()
ax=Axes3D(fig)
X = np.arange(-4,4,0.25)
Y = np.arange(-4,4,0.25)
X,Y = np.meshgrid(X,Y)
R = np.sqrt(X**2+Y**2)
Z = np.sin(R)
ax.plot_surface(X,Y,Z,rstride=1,cstride=1,cmap=plt.get_cmap('rainbow')) #rstride=1,cstride=1 行和列的跨度
ax.contourf(X,Y,Z,zdir='z',offset=-2,cmap='rainbow') 
ax.set_zlim(-2,2)
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp\2/ipykernel_11008/1163243075.py:5: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax=Axes3D(fig)
# (-2.0, 2.0)

# %% [markdown]
# # 子图

# %% [markdown]
# ## SubPlot子图与多合一显示

# %%
plt.subplot(2,2,1) #第一个子图
plt.plot([0,1],[0,1])
plt.subplot(222) 
plt.plot([0,1],[0,3],[2,4])
plt.subplot(223) 
plt.plot([0,1],[0,2])
plt.subplot(224) 
plt.plot([0,1],[0,3])

# %%
plt.subplot(2,1,1) #第一个子图
plt.plot([0,1],[0,1])
plt.subplot(234) #第一个子图
plt.plot([0,1],[0,3],[2,4])
plt.subplot(235) #第一个子图
plt.plot([0,1],[0,2])
plt.subplot(236) #第一个子图
plt.plot([0,1],[0,3])

# %% [markdown]
# ## SubPlot分格显示

# %%
# method1:subplot2grid 使用形状加坐标
plt.figure()
ax1 = plt.subplot2grid(shape=(3,3),loc=(0,0),colspan=3,rowspan=1)
ax1.plot([0,1],[1,2])
ax1.set_title("第一个图")
ax2 = plt.subplot2grid(shape=(3,3),loc=(1,0),colspan=2)
ax3 = plt.subplot2grid(shape=(3,3),loc=(1,2),rowspan=2)
ax4 = plt.subplot2grid(shape=(3,3),loc=(2,0))
ax4 = plt.subplot2grid(shape=(3,3),loc=(2,1))

# %%
# method2:gridspec  使用坐标
import matplotlib.gridspec as gridspec
plt.figure()
gs = gridspec.GridSpec(3,3) #设置一个3*3的网格
ax1=plt.subplot(gs[0,:])
ax2=plt.subplot(gs[1,0:2])
ax3=plt.subplot(gs[1:3,2])
ax4=plt.subplot(gs[2,0])
ax5=plt.subplot(gs[2,1])

# %%
# method3:subplots
fig,((ax11,ax12),(ax21,ax22))=plt.subplots(2,2,sharex=True,sharey=True)
ax21.plot([0,1],[0,2])

# %% [markdown]
# ## 图中图

# %%
#制作大图
fig=plt.figure()
x=[1,2,3,4,5,6,7]
y=[1,3,4,2,5,8,6]

left,bottom,width,height=.1,.1,.8,.8
ax1=fig.add_axes([left,bottom,width,height])
ax1.plot(x,y,'r')#r是red
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_title('title')

left,bottom,width,height=.2,.6,.25,.25
ax2=fig.add_axes([left,bottom,width,height])
ax2.plot(y,x,'b')#r是red
ax2.set_xlabel('s1x')
ax2.set_ylabel('s1y')
ax2.set_title('inside title 1')

plt.axes([.6,.2,.3,.3])
plt.plot(y[::-1],x,'g')
plt.xlabel('s2x')  # 注意 plt的设置坐标label和title方法会有不同
plt.ylabel('s2y')
plt.title('inside title 2')
# Out:
# Text(0.5, 1.0, 'inside title 2')

# %% [markdown]
# ## 次坐标

# %%
# 两个函数共享一个轴 另一个轴不相同
x = np.arange(11)
y1 = .05*x**2
y2 = -1*y1
fig,ax1 = plt.subplots()
ax2 = ax1.twinx() #将ax2和ax1的x轴镜像反转
ax1.plot(x,y1,'g--')
ax2.plot(x,y2,'b-.')
ax1.set_ylabel('Y1',color='g')
ax2.set_ylabel('Y2',color='b')
# Out:
# Text(0, 0.5, 'Y2')

# %% [markdown]
# # animation动画

# %%
from matplotlib import animation
# %matplotlib notebook
fig,ax = plt.subplots()
x = np.arange(0,2*np.pi,0.01)# np.pi=pai
line,=ax.plot(x,np.sin(x))

def aniFunc(i):
    line.set_ydata(np.sin(x+i/100))
    return line,
def init():
    line.set_ydata(np.sin(x))
    return line,

ani = animation.FuncAnimation(fig=fig,func=aniFunc,frames=100,init_func=init,interval=20,blit=False)
# Out:
# <div id='5061c956-8f07-4fa1-ab43-3c32f095bad4'></div>
# c:\users\administrator\appdata\local\programs\python\python38\lib\site-packages\matplotlib\animation.py:973: UserWarning: Animation was deleted without rendering anything. This is most likely unintended. To prevent deletion, assign the Animation to a variable that exists for as long as you need the Animation.
#   warnings.warn(

# %% [markdown]
# # 完结撒花🎉
